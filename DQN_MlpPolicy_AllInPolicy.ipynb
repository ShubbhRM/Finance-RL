# %%
import gymnasium as gym
from gymnasium import spaces

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

ticker = "MSFT"
df = yf.download(ticker, period='60d', interval="2m")

df.columns = [i[0] for i in df.columns]
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
# Function to compute RSI
def compute_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

# Function to compute MACD
def compute_macd(data, short_window=12, long_window=26, signal_window=9):
    short_ema = data.ewm(span=short_window, adjust=False).mean()
    long_ema = data.ewm(span=long_window, adjust=False).mean()
    macd = short_ema - long_ema
    signal_line = macd.ewm(span=signal_window, adjust=False).mean()
    return macd, signal_line

# Compute Indicators
df["SMA_10"] = df["High"].rolling(window=10).mean()
df["EMA_10"] = df["High"].ewm(span=10, adjust=False).mean()
df["RSI_14"] = compute_rsi(df["High"], window=14)
df["MACD"], df["Signal_Line"] = compute_macd(df["High"])
df["BB_Mid"] = df["High"].rolling(window=20).mean()
df["BB_Std"] = df["High"].rolling(window=20).std()
df["BB_Upper"] = df["BB_Mid"] + (df["BB_Std"] * 2)
df["BB_Lower"] = df["BB_Mid"] - (df["BB_Std"] * 2)

price_volume = (df["High"] * df["Volume"]).rolling(window=20).sum().shift(1)
volume_sum = df["Volume"].rolling(window=20).sum().shift(1)
df["VWAP"] = price_volume / volume_sum


fib_window = 26  # adjust to match your feature engineering style

rolling_high = df["High"].rolling(window=fib_window).max().shift(1)
rolling_low = df["Low"].rolling(window=fib_window).min().shift(1)

df["Fib_23.6"] = rolling_low + 0.236 * (rolling_high - rolling_low)
df["Fib_38.2"] = rolling_low + 0.382 * (rolling_high - rolling_low)
df["Fib_61.8"] = rolling_low + 0.618 * (rolling_high - rolling_low)

df.drop(columns=["BB_Std"], inplace=True)

# Shift indicators to prevent data leakage

for col in ["SMA_10", "EMA_10", "RSI_14", "MACD", "Signal_Line", "VWAP", "BB_Mid", "BB_Upper", "BB_Lower"]:
    df[col] = df[col].shift(1)

# Drop NaN values resulting from rolling calculations
df.dropna(inplace=True)

# %%
df
# Out:
#                                 Close        High         Low        Open  \
# Datetime
# 2025-02-24 15:22:00+00:00  399.679993  400.359985  399.470001  399.695007
# 2025-02-24 15:24:00+00:00  400.415009  400.670013  399.410004  399.744995
# 2025-02-24 15:26:00+00:00  399.695007  400.480011  399.369995  400.393005
# 2025-02-24 15:28:00+00:00  399.790009  399.970001  399.579987  399.684998
# 2025-02-24 15:30:00+00:00  399.910004  400.070007  399.660004  399.815002
# ...                               ...         ...         ...         ...
# 2025-04-10 19:50:00+00:00  381.320007  381.589996  378.260010  378.260010
# 2025-04-10 19:52:00+00:00  381.480011  381.989990  381.049988  381.290009
# 2025-04-10 19:54:00+00:00  380.910004  383.000000  379.260010  381.589996
# 2025-04-10 19:56:00+00:00  382.339996  383.149994  380.799988  380.809998
# 2025-04-10 19:58:00+00:00  381.140015  382.640015  380.820007  382.299988
#
#                            Volume      SMA_10      EMA_10     RSI_14  \
# Datetime
# 2025-02-24 15:22:00+00:00  176310  400.936005  401.139486  34.991452
# 2025-02-24 15:24:00+00:00  148168  400.906003  400.997759  37.455541
# 2025-02-24 15:26:00+00:00  137562  400.869003  400.938169  39.500901
# 2025-02-24 15:28:00+00:00  117335  400.885504  400.854867  38.572169
# %%
class TradingEnv(gym.Env):
    def __init__(self, df, initial_cash=1000, initial_stock=10, context_width=10, offset=3):
        super(TradingEnv, self).__init__()

        self.df = df.reset_index(drop=True)
        self.initial_cash = initial_cash
        self.initial_stock = initial_stock  # NEW

        self.context_width = context_width
        self.offset = offset
        self.num_features = df.shape[1]

        self.action_space = spaces.Discrete(3)

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(self.context_width, self.num_features + 2),
            dtype=np.float32
        )

        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = self.context_width
        self.cash = self.initial_cash
        self.stock_held = self.initial_stock  # NEW

        if seed is not None:
            np.random.seed(seed)

        obs = self._get_obs()
        info = {}
        return obs, info


    def render(self, mode="human"):
        if self.current_step >= len(self.df):
            print("End of data reached. No further rendering possible.")
            return

        price = self.df.iloc[self.current_step]["Close"]
        net_worth = self.cash + self.stock_held * price
        profit_loss = net_worth - (self.initial_cash + self.initial_stock * price)
        status = "PROFIT" if profit_loss > 0 else "LOSS" if profit_loss < 0 else "BREAKEVEN"

        print(f"Step: {self.current_step}, Cash: {self.cash:.2f}, Stock: {self.stock_held}, "
              f"Net Worth: {net_worth:.2f}, P/L: {profit_loss:.2f} ({status})")

    
    def _get_obs(self):
        window = self.df.iloc[self.current_step - self.context_width:self.current_step].values.astype(np.float32)
        cash_stock = np.array([[self.cash, self.stock_held]] * self.context_width, dtype=np.float32)
        obs = np.concatenate((window, cash_stock), axis=1)
        return obs  # 2D now: [context_width x (features + 2)]

    def step(self, action):
        terminated = False
        truncated = False
        info = {}

        current_price = self.df.iloc[self.current_step]["Close"]
        prev_total_asset = self.cash + self.stock_held * current_price
        prev_cash = self.cash
        prev_stock_held = self.stock_held

        # --- Execute All-In Actions ---
        if action == 1 and self.cash >= current_price:
            # All-In Buy: invest all available cash
            units_to_buy = int(self.cash // current_price)
            self.cash -= units_to_buy * current_price
            self.stock_held += units_to_buy

        elif action == 2 and self.stock_held > 0:
            # All-Out Sell: liquidate all stock
            self.cash += self.stock_held * current_price
            self.stock_held = 0

        # else: HOLD → maintain current position

        self.current_step += 1

        # Check if we're at the end of the data
        if self.current_step + self.offset >= len(self.df):
            terminated = True
            self.current_step = len(self.df) - 1

        # Calculate reward based on future price
        next_price = self.df.iloc[min(self.current_step, len(self.df) - 1)]["Close"]
        current_total_asset = self.cash + self.stock_held * next_price
        reward = current_total_asset - prev_total_asset

        # --- Additional HOLD Reward Logic ---
        if action == 0:
            price_diff = next_price - current_price
            if prev_stock_held > 0:
                reward += price_diff  # reward holding if price went up
            else:
                reward -= abs(price_diff) * 0.1  # light penalty for cash hold if missed gains

        obs = self._get_obs()
        return obs, reward, terminated, truncated, info

# %%
df
# Out:
#                                 Close        High         Low        Open  \
# Datetime
# 2025-02-24 15:22:00+00:00  399.679993  400.359985  399.470001  399.695007
# 2025-02-24 15:24:00+00:00  400.415009  400.670013  399.410004  399.744995
# 2025-02-24 15:26:00+00:00  399.695007  400.480011  399.369995  400.393005
# 2025-02-24 15:28:00+00:00  399.790009  399.970001  399.579987  399.684998
# 2025-02-24 15:30:00+00:00  399.910004  400.070007  399.660004  399.815002
# ...                               ...         ...         ...         ...
# 2025-04-10 19:50:00+00:00  381.320007  381.589996  378.260010  378.260010
# 2025-02-24 15:24:00+00:00  405.345507
# 2025-02-24 15:26:00+00:00  404.066243
# 2025-02-24 15:28:00+00:00  402.830243
# 2025-02-24 15:30:00+00:00  402.428547
# ...                               ...
# 2025-04-10 19:50:00+00:00  381.180701
# 2025-04-10 19:52:00+00:00  381.180701
# 2025-04-10 19:54:00+00:00  381.180701
# 2025-04-10 19:56:00+00:00  381.180701
# 2025-04-10 19:58:00+00:00  381.180701
#
# [6593 rows x 17 columns]

# %%
# ---------------------------
# Training
# ---------------------------
context_width = 10
offset = 1

split_point = int(len(df) * 0.7)
train_df = df[:split_point]
test_df = df[split_point:]

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN

train_env = TradingEnv(train_df, context_width=context_width, offset=offset)
train_env = DummyVecEnv([lambda: train_env])

steps_per_episode = df.shape[0] - context_width
total_timesteps = 150 * steps_per_episode

model = DQN("MlpPolicy", train_env, verbose=1)
model.learn(total_timesteps=total_timesteps)
# Out:
# Using cuda device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 469      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 18416    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 177      |
# |    n_updates        | 4578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.646    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 458      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 36832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 279      |
# |    n_updates        | 9182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 442      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 55248    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 158      |
# |    n_updates        | 13786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 427      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 73664    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 108      |
# |    n_updates        | 18390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.114    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 412      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 92080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 308      |
# |    n_updates        | 22994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 399      |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 110496   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 146      |
# |    n_updates        | 27598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 391      |
# |    time_elapsed     | 329      |
# |    total_timesteps  | 128912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 114      |
# |    n_updates        | 32202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 385      |
# |    time_elapsed     | 382      |
# |    total_timesteps  | 147328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 95.9     |
# |    n_updates        | 36806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 380      |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 165744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 199      |
# |    n_updates        | 41410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 376      |
# |    time_elapsed     | 488      |
# |    total_timesteps  | 184160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 85       |
# |    n_updates        | 46014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 374      |
# |    time_elapsed     | 541      |
# |    total_timesteps  | 202576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 111      |
# |    n_updates        | 50618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 372      |
# |    time_elapsed     | 594      |
# |    total_timesteps  | 220992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 76.8     |
# |    n_updates        | 55222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 370      |
# |    time_elapsed     | 646      |
# |    total_timesteps  | 239408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 60.7     |
# |    n_updates        | 59826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 368      |
# |    time_elapsed     | 699      |
# |    total_timesteps  | 257824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 144      |
# |    n_updates        | 64430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 366      |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 276240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 144      |
# |    n_updates        | 69034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 365      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 294656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 68.7     |
# |    n_updates        | 73638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 363      |
# |    time_elapsed     | 860      |
# |    total_timesteps  | 313072   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 62.9     |
# |    n_updates        | 78242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 362      |
# |    time_elapsed     | 913      |
# |    total_timesteps  | 331488   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 63.4     |
# |    n_updates        | 82846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 361      |
# |    time_elapsed     | 967      |
# |    total_timesteps  | 349904   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.5     |
# |    n_updates        | 87450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 360      |
# |    time_elapsed     | 1022     |
# |    total_timesteps  | 368320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 71       |
# |    n_updates        | 92054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 359      |
# |    time_elapsed     | 1076     |
# |    total_timesteps  | 386736   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 98.3     |
# |    n_updates        | 96658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 358      |
# |    time_elapsed     | 1130     |
# |    total_timesteps  | 405152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 58.7     |
# |    n_updates        | 101262   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 358      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 423568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 55.6     |
# |    n_updates        | 105866   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 357      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 441984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 88.5     |
# |    n_updates        | 110470   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 357      |
# |    time_elapsed     | 1289     |
# |    total_timesteps  | 460400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 72.7     |
# |    n_updates        | 115074   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 356      |
# |    time_elapsed     | 1343     |
# |    total_timesteps  | 478816   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 153      |
# |    n_updates        | 119678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 355      |
# |    time_elapsed     | 1398     |
# |    total_timesteps  | 497232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37       |
# |    n_updates        | 124282   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 354      |
# |    time_elapsed     | 1453     |
# |    total_timesteps  | 515648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.7     |
# |    n_updates        | 128886   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 354      |
# |    time_elapsed     | 1507     |
# |    total_timesteps  | 534064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 67.1     |
# |    n_updates        | 133490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 354      |
# |    time_elapsed     | 1560     |
# |    total_timesteps  | 552480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 48       |
# |    n_updates        | 138094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 354      |
# |    time_elapsed     | 1611     |
# |    total_timesteps  | 570896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 130      |
# |    n_updates        | 142698   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 354      |
# |    time_elapsed     | 1662     |
# |    total_timesteps  | 589312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 24.6     |
# |    n_updates        | 147302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 354      |
# |    time_elapsed     | 1714     |
# |    total_timesteps  | 607728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.3     |
# |    n_updates        | 151906   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 354      |
# |    time_elapsed     | 1767     |
# |    total_timesteps  | 626144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.3     |
# |    n_updates        | 156510   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 353      |
# |    time_elapsed     | 1820     |
# |    total_timesteps  | 644560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 30.5     |
# |    n_updates        | 161114   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 353      |
# |    time_elapsed     | 1875     |
# |    total_timesteps  | 662976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 32.5     |
# |    n_updates        | 165718   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 353      |
# |    time_elapsed     | 1927     |
# |    total_timesteps  | 681392   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 31       |
# |    n_updates        | 170322   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 352      |
# |    time_elapsed     | 1982     |
# |    total_timesteps  | 699808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 30.7     |
# |    n_updates        | 174926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 351      |
# |    time_elapsed     | 2045     |
# |    total_timesteps  | 718224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.4     |
# |    n_updates        | 179530   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 349      |
# |    time_elapsed     | 2107     |
# |    total_timesteps  | 736640   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.8     |
# |    n_updates        | 184134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 348      |
# |    time_elapsed     | 2169     |
# |    total_timesteps  | 755056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 27.3     |
# |    n_updates        | 188738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 346      |
# |    time_elapsed     | 2230     |
# |    total_timesteps  | 773472   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.7     |
# |    n_updates        | 193342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 345      |
# |    time_elapsed     | 2292     |
# |    total_timesteps  | 791888   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 27.8     |
# |    n_updates        | 197946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 344      |
# |    time_elapsed     | 2354     |
# |    total_timesteps  | 810304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 22.3     |
# |    n_updates        | 202550   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 342      |
# |    time_elapsed     | 2417     |
# |    total_timesteps  | 828720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 26.1     |
# |    n_updates        | 207154   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 341      |
# |    time_elapsed     | 2480     |
# |    total_timesteps  | 847136   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 20.7     |
# |    n_updates        | 211758   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 340      |
# |    time_elapsed     | 2543     |
# |    total_timesteps  | 865552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 22.2     |
# |    n_updates        | 216362   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 339      |
# |    time_elapsed     | 2603     |
# |    total_timesteps  | 883968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 24.1     |
# |    n_updates        | 220966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 338      |
# |    time_elapsed     | 2663     |
# |    total_timesteps  | 902384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 24.7     |
# |    n_updates        | 225570   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 337      |
# |    time_elapsed     | 2724     |
# |    total_timesteps  | 920800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 16.4     |
# |    n_updates        | 230174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 337      |
# |    time_elapsed     | 2785     |
# |    total_timesteps  | 939216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.6     |
# |    n_updates        | 234778   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 336      |
# |    time_elapsed     | 2846     |
# |    total_timesteps  | 957632   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 21.4     |
# |    n_updates        | 239382   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 335      |
# |    time_elapsed     | 2907     |
# |    total_timesteps  | 976048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 24.1     |
# |    n_updates        | 243986   |
# ----------------------------------

# %%
# ---------------------------
# Evaluation
# ---------------------------
import matplotlib.pyplot as plt

test_env = TradingEnv(test_df[:100], context_width=context_width, offset=offset)
obs, _ = test_env.reset()
done = False

# Logs
actions = []
prices = []
net_worths = []

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, _ = test_env.step(action)

    # Logging actions, prices, net worth...
    actions.append(action)
    current_price = test_df.iloc[test_env.current_step]["Close"]
    current_value = test_env.cash + test_env.stock_held * current_price
    prices.append(current_price)
    net_worths.append(current_value)

    # SEE RENDER OUTPUT
    test_env.render()  

# ---------------------------
# Plot Trading Signals
# ---------------------------
buy_indices = [i for i, a in enumerate(actions) if a == 1]
sell_indices = [i for i, a in enumerate(actions) if a == 2]
hold_indices = [i for i, a in enumerate(actions) if a == 0]

plt.figure(figsize=(14, 6))
plt.plot(prices, label='Price', linewidth=2)
plt.scatter(buy_indices, [prices[i] for i in buy_indices], marker='^', color='g', s=100, label='Buy')
plt.scatter(sell_indices, [prices[i] for i in sell_indices], marker='v', color='r', s=100, label='Sell')
plt.scatter(hold_indices, [prices[i] for i in hold_indices], marker='.', color='gray', alpha=0.3, label='Hold')
plt.title("Agent's Trading Signals on Price Chart")
plt.xlabel("Step")
plt.ylabel("Price ($)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ---------------------------
# Plot Net Worth
# ---------------------------
plt.figure(figsize=(12, 4))
plt.plot(net_worths, label='Net Worth', linewidth=2)
plt.title("Net Worth Over Time During Evaluation")
plt.xlabel("Step")
plt.ylabel("Total Asset Value ($)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Step: 11, Cash: 216.43, Stock: 12, Net Worth: 4918.27, P/L: 0.07 (PROFIT)
# Step: 12, Cash: 216.43, Stock: 12, Net Worth: 4917.67, P/L: -0.03 (LOSS)
# Step: 13, Cash: 216.43, Stock: 12, Net Worth: 4921.27, P/L: 0.57 (PROFIT)
# Step: 14, Cash: 216.43, Stock: 12, Net Worth: 4921.27, P/L: 0.57 (PROFIT)
# Step: 15, Cash: 216.43, Stock: 12, Net Worth: 4921.53, P/L: 0.61 (PROFIT)
# Step: 16, Cash: 216.43, Stock: 12, Net Worth: 4920.31, P/L: 0.41 (PROFIT)
# Step: 17, Cash: 216.43, Stock: 12, Net Worth: 4920.43, P/L: 0.43 (PROFIT)
# Step: 18, Cash: 216.43, Stock: 12, Net Worth: 4913.29, P/L: -0.76 (LOSS)
# Step: 19, Cash: 216.43, Stock: 12, Net Worth: 4913.23, P/L: -0.77 (LOSS)
# Step: 20, Cash: 216.43, Stock: 12, Net Worth: 4912.45, P/L: -0.90 (LOSS)
# Step: 80, Cash: 214.58, Stock: 12, Net Worth: 4802.12, P/L: -20.83 (LOSS)
# Step: 81, Cash: 214.58, Stock: 12, Net Worth: 4799.13, P/L: -21.33 (LOSS)
# Step: 82, Cash: 214.58, Stock: 12, Net Worth: 4800.86, P/L: -21.04 (LOSS)
# Step: 83, Cash: 214.58, Stock: 12, Net Worth: 4805.58, P/L: -20.25 (LOSS)
# Step: 84, Cash: 214.58, Stock: 12, Net Worth: 4803.92, P/L: -20.53 (LOSS)
# Step: 85, Cash: 4803.92, Stock: 0, Net Worth: 4803.92, P/L: -17.08 (LOSS)
# Step: 86, Cash: 218.72, Stock: 12, Net Worth: 4805.30, P/L: -16.85 (LOSS)
# Step: 87, Cash: 218.72, Stock: 12, Net Worth: 4804.13, P/L: -17.04 (LOSS)
# Step: 88, Cash: 218.72, Stock: 12, Net Worth: 4798.57, P/L: -17.97 (LOSS)
# Step: 89, Cash: 218.72, Stock: 12, Net Worth: 4799.12, P/L: -17.88 (LOSS)
# Step: 90, Cash: 218.72, Stock: 12, Net Worth: 4803.20, P/L: -17.20 (LOSS)
# Step: 91, Cash: 218.72, Stock: 12, Net Worth: 4808.48, P/L: -16.32 (LOSS)
# Step: 92, Cash: 218.72, Stock: 12, Net Worth: 4810.16, P/L: -16.04 (LOSS)
# Step: 93, Cash: 218.72, Stock: 12, Net Worth: 4811.24, P/L: -15.86 (LOSS)
# Step: 94, Cash: 218.72, Stock: 12, Net Worth: 4811.72, P/L: -15.78 (LOSS)
# Step: 95, Cash: 218.72, Stock: 12, Net Worth: 4812.32, P/L: -15.68 (LOSS)
# Step: 96, Cash: 218.72, Stock: 12, Net Worth: 4814.84, P/L: -15.26 (LOSS)
# Step: 97, Cash: 218.72, Stock: 12, Net Worth: 4810.34, P/L: -16.01 (LOSS)
# Step: 98, Cash: 218.72, Stock: 12, Net Worth: 4804.76, P/L: -16.94 (LOSS)
# Step: 99, Cash: 218.72, Stock: 12, Net Worth: 4803.44, P/L: -17.16 (LOSS)

# %%
# ---------------------------
# Evaluation
# ---------------------------
import matplotlib.pyplot as plt

test_env = TradingEnv(test_df[100:300], context_width=context_width, offset=offset)
obs, _ = test_env.reset()
done = False

# Logs
actions = []
prices = []
net_worths = []

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, _ = test_env.step(action)

    # Tracking
    actions.append(action)
    current_price = test_df.iloc[test_env.current_step]["Close"]
    current_value = test_env.cash + test_env.stock_held * current_price
    prices.append(current_price)
    net_worths.append(current_value)

# ---------------------------
# Plot Trading Signals
# ---------------------------
buy_indices = [i for i, a in enumerate(actions) if a == 1]
sell_indices = [i for i, a in enumerate(actions) if a == 2]
hold_indices = [i for i, a in enumerate(actions) if a == 0]

plt.figure(figsize=(14, 6))
plt.plot(prices, label='Price', linewidth=2)
plt.scatter(buy_indices, [prices[i] for i in buy_indices], marker='^', color='g', s=100, label='Buy')
plt.scatter(sell_indices, [prices[i] for i in sell_indices], marker='v', color='r', s=100, label='Sell')
plt.scatter(hold_indices, [prices[i] for i in hold_indices], marker='.', color='gray', alpha=0.3, label='Hold')
plt.title("Agent's Trading Signals on Price Chart")
plt.xlabel("Step")
plt.ylabel("Price ($)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ---------------------------
# Plot Net Worth
# ---------------------------
plt.figure(figsize=(12, 4))
plt.plot(net_worths, label='Net Worth', linewidth=2)
plt.title("Net Worth Over Time During Evaluation")
plt.xlabel("Step")
plt.ylabel("Total Asset Value ($)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ---------------------------
# Evaluation
# ---------------------------
import matplotlib.pyplot as plt

test_env = TradingEnv(test_df[300:500], context_width=context_width, offset=offset)
obs, _ = test_env.reset()
done = False

# Logs
actions = []
prices = []
net_worths = []

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, _ = test_env.step(action)

    # Tracking
    actions.append(action)
    current_price = test_df.iloc[test_env.current_step]["Close"]
    current_value = test_env.cash + test_env.stock_held * current_price
    prices.append(current_price)
    net_worths.append(current_value)

# ---------------------------
# Plot Trading Signals
# ---------------------------
buy_indices = [i for i, a in enumerate(actions) if a == 1]
sell_indices = [i for i, a in enumerate(actions) if a == 2]
hold_indices = [i for i, a in enumerate(actions) if a == 0]

plt.figure(figsize=(14, 6))
plt.plot(prices, label='Price', linewidth=2)
plt.scatter(buy_indices, [prices[i] for i in buy_indices], marker='^', color='g', s=100, label='Buy')
plt.scatter(sell_indices, [prices[i] for i in sell_indices], marker='v', color='r', s=100, label='Sell')
plt.scatter(hold_indices, [prices[i] for i in hold_indices], marker='.', color='gray', alpha=0.3, label='Hold')
plt.title("Agent's Trading Signals on Price Chart")
plt.xlabel("Step")
plt.ylabel("Price ($)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ---------------------------
# Plot Net Worth
# ---------------------------
plt.figure(figsize=(12, 4))
plt.plot(net_worths, label='Net Worth', linewidth=2)
plt.title("Net Worth Over Time During Evaluation")
plt.xlabel("Step")
plt.ylabel("Total Asset Value ($)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ---------------------------
# Evaluation
# ---------------------------
import matplotlib.pyplot as plt

test_env = TradingEnv(test_df[500:], context_width=context_width, offset=offset)
obs, _ = test_env.reset()
done = False

# Logs
actions = []
prices = []
net_worths = []

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, _ = test_env.step(action)

    # Tracking
    actions.append(action)
    current_price = test_df.iloc[test_env.current_step]["Close"]
    current_value = test_env.cash + test_env.stock_held * current_price
    prices.append(current_price)
    net_worths.append(current_value)

# ---------------------------
# Plot Trading Signals
# ---------------------------
buy_indices = [i for i, a in enumerate(actions) if a == 1]
sell_indices = [i for i, a in enumerate(actions) if a == 2]
hold_indices = [i for i, a in enumerate(actions) if a == 0]

plt.figure(figsize=(14, 6))
plt.plot(prices, label='Price', linewidth=2)
plt.scatter(buy_indices, [prices[i] for i in buy_indices], marker='^', color='g', s=100, label='Buy')
plt.scatter(sell_indices, [prices[i] for i in sell_indices], marker='v', color='r', s=100, label='Sell')
plt.scatter(hold_indices, [prices[i] for i in hold_indices], marker='.', color='gray', alpha=0.3, label='Hold')
plt.title("Agent's Trading Signals on Price Chart")
plt.xlabel("Step")
plt.ylabel("Price ($)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ---------------------------
# Plot Net Worth
# ---------------------------
plt.figure(figsize=(12, 4))
plt.plot(net_worths, label='Net Worth', linewidth=2)
plt.title("Net Worth Over Time During Evaluation")
plt.xlabel("Step")
plt.ylabel("Total Asset Value ($)")
plt.grid(True)
plt.tight_layout()
plt.show()
